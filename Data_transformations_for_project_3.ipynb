# %%
# %matplotlib notebook

# %%
pip install psycopg2
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.2 MB 3.2 MB/s eta 0:00:01
#    ------ --------------------------------- 0.2/1.2 MB 2.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 0.9/1.2 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 8.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import psycopg2
from psycopg2 import sql

# %%
# Read CSV
P1_data = pd.read_csv("C:/Users/oury/Documents/GitHub/project3/resources/Annual_P_L_1_final.csv")
P2_data = pd.read_csv("C:/Users/oury/Documents/GitHub/project3/resources/Annual_P_L_2_final.csv")
P1_data.head()
# Out:
#                Name  BSE Code    NSE Code  \
# 0        20 Microns  533022.0   20MICRONS
# 1  21st Cent. Mgmt.  526921.0  21STCENMGM
# 2           360 ONE  542772.0      360ONE
# 3       3B Blackbio  532067.0      __NA__
# 4   3C IT Solutions  544190.0      __NA__
#
#                                 Industry  Current Price    Sales    OPM  \
# 0             Mining / Minerals / Metals         224.55   777.49  13.59
# 1                  Finance & Investments          70.44    34.92  94.27
# 2                  Finance & Investments        1009.40  2920.91  58.37
# 3                             Healthcare        1182.00    74.12  44.50
# 4  Computers - Software - Medium / Small          44.01    61.93   5.17
#
#    Profit after tax  Return on capital employed    EPS  ...  \
# 0             57.38                       21.70  15.89  ...
# 1             32.23                       73.00  30.70  ...
# 2            804.18                       14.47  22.41  ...
# ...

# %%
P2_data.head()
# Out:
#                Name  BSE Code    NSE Code  \
# 0        20 Microns  533022.0   20MICRONS
# 1  21st Cent. Mgmt.  526921.0  21STCENMGM
# 2           360 ONE  542772.0      360ONE
# 3       3B Blackbio  532067.0      __NA__
# 4   3C IT Solutions  544190.0      __NA__
#
#                                 Industry  Current Price  Sales growth 3Years  \
# 0             Mining / Minerals / Metals         224.65                17.15
# 1                  Finance & Investments          70.44                  NaN
# 2                  Finance & Investments        1007.00                20.86
# 3                             Healthcare        1186.85               -31.11
# 4  Computers - Software - Medium / Small          44.01                  NaN
#
#    Sales growth 5Years  Profit growth 3Years  Profit growth 5Years  \
# 0                10.14                 35.20                 17.97
# 1                32.41                121.08                 42.37
# ...

# %%
# Specify the column to split
column_to_split = "Industry"

# Split the column into 'main' and 'sub'
P1_data[['Main Industry', 'Sub Industry']] = P1_data[column_to_split].str.split('/', expand=True, n=1)


# Display the updated DataFrame
P1_data.head()
# Out:
#                Name  BSE Code    NSE Code  \
# 0        20 Microns  533022.0   20MICRONS
# 1  21st Cent. Mgmt.  526921.0  21STCENMGM
# 2           360 ONE  542772.0      360ONE
# 3       3B Blackbio  532067.0      __NA__
# 4   3C IT Solutions  544190.0      __NA__
#
#                                 Industry  Current Price    Sales    OPM  \
# 0             Mining / Minerals / Metals         224.55   777.49  13.59
# 1                  Finance & Investments          70.44    34.92  94.27
# 2                  Finance & Investments        1009.40  2920.91  58.37
# 3                             Healthcare        1182.00    74.12  44.50
# 4  Computers - Software - Medium / Small          44.01    61.93   5.17
#
#    Profit after tax  Return on capital employed    EPS  ...  \
# 0             57.38                       21.70  15.89  ...
# 1             32.23                       73.00  30.70  ...
# 2            804.18                       14.47  22.41  ...
# ...

# %%
#moving main industry column
column_to_move = 'Main Industry'
after_column = 'Industry'
columns = P1_data.columns.tolist()
columns.remove(column_to_move)
position = columns.index(after_column) + 1
columns.insert(position, column_to_move)

P1_data = P1_data[columns]
P1_data.head(30)
# Out:
#                 Name  BSE Code    NSE Code  \
# 0         20 Microns  533022.0   20MICRONS
# 1   21st Cent. Mgmt.  526921.0  21STCENMGM
# 2            360 ONE  542772.0      360ONE
# 3        3B Blackbio  532067.0      __NA__
# 4    3C IT Solutions  544190.0      __NA__
# 5        3i Infotech  532628.0   3IINFOLTD
# 6           3M India  523395.0     3MINDIA
# 7      3P Land Hold.  516092.0      3PLAND
# 8    52 Weeks Enter.  531925.0      __NA__
# 9     5Paisa Capital  540776.0      5PAISA
# 10    63 Moons Tech.  526881.0     63MOONS
# 11    7NR Retail Ltd  540615.0      __NA__
# 12      7Seas Enter.  540874.0      __NA__
# 13             A B B  500002.0         ABB
# 14    A B Infrabuild      -1.0     ABINFRA
# 15  A B M Internatl.      -1.0  ABMINTLLTD
# 16   A F Enterprises  538351.0      __NA__
# 17     A G Universal      -1.0        AGUL
# 18       A K Spintex  539300.0      __NA__
# 19     A R C Finance  540135.0      __NA__
# 20          A-1 Acid  542012.0      __NA__
# ...

# %%
#Moving sub industry column
column_to_move = 'Sub Industry'
after_column = 'Main Industry'
columns = P1_data.columns.tolist()
columns.remove(column_to_move)
position = columns.index(after_column) + 1
columns.insert(position, column_to_move)

P1_data = P1_data[columns]
P1_data.head(30)
# Out:
#                 Name  BSE Code    NSE Code  \
# 0         20 Microns  533022.0   20MICRONS
# 1   21st Cent. Mgmt.  526921.0  21STCENMGM
# 2            360 ONE  542772.0      360ONE
# 3        3B Blackbio  532067.0      __NA__
# 4    3C IT Solutions  544190.0      __NA__
# 5        3i Infotech  532628.0   3IINFOLTD
# 6           3M India  523395.0     3MINDIA
# 7      3P Land Hold.  516092.0      3PLAND
# 8    52 Weeks Enter.  531925.0      __NA__
# 9     5Paisa Capital  540776.0      5PAISA
# 10    63 Moons Tech.  526881.0     63MOONS
# 11    7NR Retail Ltd  540615.0      __NA__
# 12      7Seas Enter.  540874.0      __NA__
# 13             A B B  500002.0         ABB
# 14    A B Infrabuild      -1.0     ABINFRA
# 15  A B M Internatl.      -1.0  ABMINTLLTD
# 16   A F Enterprises  538351.0      __NA__
# 17     A G Universal      -1.0        AGUL
# 18       A K Spintex  539300.0      __NA__
# 19     A R C Finance  540135.0      __NA__
# 20          A-1 Acid  542012.0      __NA__
# ...

# %%
# Specify the column to split
column_to_split = "Industry"

# Split the column into 'main' and 'sub'
P2_data[['Main Industry', 'Sub Industry']] = P2_data[column_to_split].str.split('/', expand=True, n=1)


# Display the updated DataFrame
P2_data.head()
# Out:
#                Name  BSE Code    NSE Code  \
# 0        20 Microns  533022.0   20MICRONS
# 1  21st Cent. Mgmt.  526921.0  21STCENMGM
# 2           360 ONE  542772.0      360ONE
# 3       3B Blackbio  532067.0      __NA__
# 4   3C IT Solutions  544190.0      __NA__
#
#                                 Industry  Current Price  Sales growth 3Years  \
# 0             Mining / Minerals / Metals         224.65                17.15
# 1                  Finance & Investments          70.44                  NaN
# 2                  Finance & Investments        1007.00                20.86
# 3                             Healthcare        1186.85               -31.11
# 4  Computers - Software - Medium / Small          44.01                  NaN
#
#    Sales growth 5Years  Profit growth 3Years  Profit growth 5Years  \
# 0                10.14                 35.20                 17.97
# 1                32.41                121.08                 42.37
# ...

# %%
#moving main industry column
column_to_move = 'Main Industry'
after_column = 'Industry'
columns = P2_data.columns.tolist()
columns.remove(column_to_move)
position = columns.index(after_column) + 1
columns.insert(position, column_to_move)

P2_data = P2_data[columns]
P2_data.head(30)
# Out:
#                 Name  BSE Code    NSE Code  \
# 0         20 Microns  533022.0   20MICRONS
# 1   21st Cent. Mgmt.  526921.0  21STCENMGM
# 2            360 ONE  542772.0      360ONE
# 3        3B Blackbio  532067.0      __NA__
# 4    3C IT Solutions  544190.0      __NA__
# 5        3i Infotech  532628.0   3IINFOLTD
# 6           3M India  523395.0     3MINDIA
# 7      3P Land Hold.  516092.0      3PLAND
# 8    52 Weeks Enter.  531925.0      __NA__
# 9     5Paisa Capital  540776.0      5PAISA
# 10    63 Moons Tech.  526881.0     63MOONS
# 11    7NR Retail Ltd  540615.0      __NA__
# 12      7Seas Enter.  540874.0      __NA__
# 13             A B B  500002.0         ABB
# 14    A B Infrabuild      -1.0     ABINFRA
# 15  A B M Internatl.      -1.0  ABMINTLLTD
# 16   A F Enterprises  538351.0      __NA__
# 17     A G Universal      -1.0        AGUL
# 18       A K Spintex  539300.0      __NA__
# 19     A R C Finance  540135.0      __NA__
# 20          A-1 Acid  542012.0      __NA__
# ...

# %%
#Moving sun industry column
column_to_move = 'Sub Industry'
after_column = 'Main Industry'
columns = P2_data.columns.tolist()
columns.remove(column_to_move)
position = columns.index(after_column) + 1
columns.insert(position, column_to_move)

P2_data = P2_data[columns]
P2_data.head(30)
# Out:
#                 Name  BSE Code    NSE Code  \
# 0         20 Microns  533022.0   20MICRONS
# 1   21st Cent. Mgmt.  526921.0  21STCENMGM
# 2            360 ONE  542772.0      360ONE
# 3        3B Blackbio  532067.0      __NA__
# 4    3C IT Solutions  544190.0      __NA__
# 5        3i Infotech  532628.0   3IINFOLTD
# 6           3M India  523395.0     3MINDIA
# 7      3P Land Hold.  516092.0      3PLAND
# 8    52 Weeks Enter.  531925.0      __NA__
# 9     5Paisa Capital  540776.0      5PAISA
# 10    63 Moons Tech.  526881.0     63MOONS
# 11    7NR Retail Ltd  540615.0      __NA__
# 12      7Seas Enter.  540874.0      __NA__
# 13             A B B  500002.0         ABB
# 14    A B Infrabuild      -1.0     ABINFRA
# 15  A B M Internatl.      -1.0  ABMINTLLTD
# 16   A F Enterprises  538351.0      __NA__
# 17     A G Universal      -1.0        AGUL
# 18       A K Spintex  539300.0      __NA__
# 19     A R C Finance  540135.0      __NA__
# 20          A-1 Acid  542012.0      __NA__
# ...

# %%
P2_data['Growth/Decline (3 years)?'] = P2_data['Sales growth 3Years'].apply(
    lambda x: 'growth' if x > 0 else ('neutral' if x == 0 else 'decline')
)
P2_data.head()
# Out:
#                Name  BSE Code    NSE Code  \
# 0        20 Microns  533022.0   20MICRONS
# 1  21st Cent. Mgmt.  526921.0  21STCENMGM
# 2           360 ONE  542772.0      360ONE
# 3       3B Blackbio  532067.0      __NA__
# 4   3C IT Solutions  544190.0      __NA__
#
#                                 Industry                   Main Industry  \
# 0             Mining / Minerals / Metals                         Mining
# 1                  Finance & Investments           Finance & Investments
# 2                  Finance & Investments           Finance & Investments
# 3                             Healthcare                      Healthcare
# 4  Computers - Software - Medium / Small  Computers - Software - Medium
#
#          Sub Industry  Current Price  Sales growth 3Years  \
# 0   Minerals / Metals         224.65                17.15
# 1                None          70.44                  NaN
# 2                None        1007.00                20.86
# ...

# %%
column_to_move = 'Growth/Decline (3 years)?'
after_column = 'Sales growth 3Years'
columns = P2_data.columns.tolist()
columns.remove(column_to_move)
position = columns.index(after_column) + 1
columns.insert(position, column_to_move)

P2_data = P2_data[columns]
P2_data.head(30)
# Out:
#                 Name  BSE Code    NSE Code  \
# 0         20 Microns  533022.0   20MICRONS
# 1   21st Cent. Mgmt.  526921.0  21STCENMGM
# 2            360 ONE  542772.0      360ONE
# 3        3B Blackbio  532067.0      __NA__
# 4    3C IT Solutions  544190.0      __NA__
# 5        3i Infotech  532628.0   3IINFOLTD
# 6           3M India  523395.0     3MINDIA
# 7      3P Land Hold.  516092.0      3PLAND
# 8    52 Weeks Enter.  531925.0      __NA__
# 9     5Paisa Capital  540776.0      5PAISA
# 10    63 Moons Tech.  526881.0     63MOONS
# 11    7NR Retail Ltd  540615.0      __NA__
# 12      7Seas Enter.  540874.0      __NA__
# 13             A B B  500002.0         ABB
# 14    A B Infrabuild      -1.0     ABINFRA
# 15  A B M Internatl.      -1.0  ABMINTLLTD
# 16   A F Enterprises  538351.0      __NA__
# 17     A G Universal      -1.0        AGUL
# 18       A K Spintex  539300.0      __NA__
# 19     A R C Finance  540135.0      __NA__
# 20          A-1 Acid  542012.0      __NA__
# ...

# %%
# Calculating the difference in net profit from last year and preceeding year
P1_data['Difference in Net Profit btw Last Year and Preceeding Year'] = P1_data['Net Profit last year'] - P1_data['Net profit preceding 12months']
P1_data.head(30)
# Out:
#                 Name  BSE Code    NSE Code  \
# 0         20 Microns  533022.0   20MICRONS
# 1   21st Cent. Mgmt.  526921.0  21STCENMGM
# 2            360 ONE  542772.0      360ONE
# 3        3B Blackbio  532067.0      __NA__
# 4    3C IT Solutions  544190.0      __NA__
# 5        3i Infotech  532628.0   3IINFOLTD
# 6           3M India  523395.0     3MINDIA
# 7      3P Land Hold.  516092.0      3PLAND
# 8    52 Weeks Enter.  531925.0      __NA__
# 9     5Paisa Capital  540776.0      5PAISA
# 10    63 Moons Tech.  526881.0     63MOONS
# 11    7NR Retail Ltd  540615.0      __NA__
# 12      7Seas Enter.  540874.0      __NA__
# 13             A B B  500002.0         ABB
# 14    A B Infrabuild      -1.0     ABINFRA
# 15  A B M Internatl.      -1.0  ABMINTLLTD
# 16   A F Enterprises  538351.0      __NA__
# 17     A G Universal      -1.0        AGUL
# 18       A K Spintex  539300.0      __NA__
# 19     A R C Finance  540135.0      __NA__
# 20          A-1 Acid  542012.0      __NA__
# ...

# %%
column_to_move = 'Difference in Net Profit btw Last Year and Preceeding Year'
after_column = 'Net profit preceding 12months'
columns = P1_data.columns.tolist()
columns.remove(column_to_move)
position = columns.index(after_column) + 1
columns.insert(position, column_to_move)

P1_data = P1_data[columns]
P1_data.head(30)
# Out:
#                 Name  BSE Code    NSE Code  \
# 0         20 Microns  533022.0   20MICRONS
# 1   21st Cent. Mgmt.  526921.0  21STCENMGM
# 2            360 ONE  542772.0      360ONE
# 3        3B Blackbio  532067.0      __NA__
# 4    3C IT Solutions  544190.0      __NA__
# 5        3i Infotech  532628.0   3IINFOLTD
# 6           3M India  523395.0     3MINDIA
# 7      3P Land Hold.  516092.0      3PLAND
# 8    52 Weeks Enter.  531925.0      __NA__
# 9     5Paisa Capital  540776.0      5PAISA
# 10    63 Moons Tech.  526881.0     63MOONS
# 11    7NR Retail Ltd  540615.0      __NA__
# 12      7Seas Enter.  540874.0      __NA__
# 13             A B B  500002.0         ABB
# 14    A B Infrabuild      -1.0     ABINFRA
# 15  A B M Internatl.      -1.0  ABMINTLLTD
# 16   A F Enterprises  538351.0      __NA__
# 17     A G Universal      -1.0        AGUL
# 18       A K Spintex  539300.0      __NA__
# 19     A R C Finance  540135.0      __NA__
# 20          A-1 Acid  542012.0      __NA__
# ...

# %%
filtered_P1_data = P1_data[P1_data['Difference in Net Profit btw Last Year and Preceeding Year'] > 0]

filtered_P1_data.head(30)
# Out:
#                 Name  BSE Code    NSE Code  \
# 0         20 Microns  533022.0   20MICRONS
# 1   21st Cent. Mgmt.  526921.0  21STCENMGM
# 2            360 ONE  542772.0      360ONE
# 3        3B Blackbio  532067.0      __NA__
# 6           3M India  523395.0     3MINDIA
# 7      3P Land Hold.  516092.0      3PLAND
# 8    52 Weeks Enter.  531925.0      __NA__
# 10    63 Moons Tech.  526881.0     63MOONS
# 12      7Seas Enter.  540874.0      __NA__
# 16   A F Enterprises  538351.0      __NA__
# 18       A K Spintex  539300.0      __NA__
# 19     A R C Finance  540135.0      __NA__
# 21  A.K.Capital Serv  530499.0      __NA__
# 22   A2Z Infra Engg.  533292.0    A2ZINFRA
# 26   Aadi Industries  530027.0      __NA__
# 27    Aakash Explor.      -1.0      AAKASH
# 29     Aanchal Ispat  538812.0      __NA__
# 30       Aarey Drugs  524412.0  AAREYDRUGS
# 31   Aarnav Fashions  539562.0      __NA__
# 32  Aaron Industries      -1.0       AARON
# 36      Aarti Pharma  543748.0  AARTIPHARM
# ...

# %%
# PostgreSQL connection details
conn_params = {
    'dbname': 'project_3',
    'user': 'your_username',
    'password': 'your_password',
    'host': 'localhost',
    'port': 5432
}

# Connect to PostgreSQL
try:
    conn = psycopg2.connect(**conn_params)
    cursor = conn.cursor()
    print("Connection successful")

    # Create table if it doesn't exist
    create_table_query = """
    CREATE TABLE "annual_p_l_1" (
  "join_key" varchar PRIMARY KEY,
  "Name" varchar,
  "BSE_Code" numeric,
  "NSE_Code" varchar,
  "Industry" varchar,
  "Main Industry" varchar,
  "Sub Industry" varchar,
  "Current_Price" numeric,
  "Sales" numeric,
  "OPM" numeric,
  "Profit_after_tax" numeric,
  "Return_on_capital_employed" numeric,
  "EPS" numeric,
  "Change_in_promoter_holding" numeric,
  "Sales_last_year" numeric,
  "Operating_profit_last_year" numeric,
  "Other_income_last_year" numeric,
  "EBIDT_last_year" numeric,
  "Depreciation_last_year" numeric,
  "EBIT_last_year" numeric,
  "Interest_last_year" numeric,
  "Profit_before_tax_last_year" numeric,
  "Tax_last_year" numeric,
  "Profit_after_tax_last_year" numeric,
  "Extraordinary_items_last_year" numeric,
  "Net_Profit_last_year" numeric,
  "Dividend_last_year" numeric,
  "Material_cost_last_year" numeric,
  "Employee_cost_last_year" numeric,
  "OPM_last_year" numeric,
  "NPM_last_year" numeric,
  "Operating_profit" numeric,
  "Interest" numeric,
  "Depreciation" numeric,
  "EPS_last_year" numeric,
  "EBIT" numeric,
  "Net_profit" numeric,
  "Current_Tax" numeric,
  "Tax" numeric,
  "Other_income" numeric,
  "Last_annual_result_date" varchar,
  "Sales_preceding_year" numeric,
  "Operating_profit_preceding_year" numeric,
  "Other_income_preceding_year" numeric,
  "EBIDT_preceding_year" numeric,
  "Depreciation_preceding_year" numeric,
  "EBIT_preceding_year" numeric,
  "Interest_preceding_year" numeric,
  "Profit_before_tax_preceding_year" numeric,
  "Tax_preceding_year" numeric,
  "Profit_after_tax_preceding_year" numeric,
  "Extraordinary_items_preceding_year" numeric,
  "Net_Profit_preceding_year" numeric,
  "Dividend_preceding_year" numeric,
  "OPM_preceding_year" numeric,
  "NPM_preceding_year" numeric,
  "EPS_preceding_year" numeric,
  "Sales_preceding_12months" numeric,
  "Net_profit_preceding_12months" numeric,
  "Difference in Net Profit btw Last Year and Preceeding Year" numeric,
  "Market_Capitalization" numeric
);

CREATE TABLE "annual_p_l_2" (
  "join_key" varchar PRIMARY KEY,
  "Name" varchar,
  "BSE_Code" numeric,
  "NSE_Code" varchar,
  "Industry" varchar,
  "Main Industry" varchar,
  "Sub Industry" varchar,
  "Current_Price" numeric,
  "Sales_growth_3Years" numeric,
  "Growth/Decline (3 years)?" numeric,
  "Sales_growth_5Years" numeric,
  "Profit_growth_3Years" numeric,
  "Profit_growth_5Years" numeric,
  "Sales_growth_10years_median" numeric,
  "Sales_growth_5years_median" numeric,
  "Sales_growth_7Years" numeric,
  "Sales_growth_10Years" numeric,
  "EBIDT_growth_3Years" numeric,
  "EBIDT_growth_5Years" numeric,
  "EBIDT_growth_7Years" numeric,
  "EBIDT_growth_10Years" numeric,
  "EPS_growth_3Years" numeric,
  "EPS_growth_5Years" numeric,
  "EPS_growth_7Years" numeric,
  "EPS_growth_10Years" numeric,
  "Profit_growth_7Years" numeric,
  "Profit_growth_10Years" numeric,
  "Change_in_promoter_holding_3Years" numeric,
  "Average_Earnings_5Year" numeric,
  "Average_Earnings_10Year" numeric,
  "Average_EBIT_5Year" numeric,
  "Average_EBIT_10Year" numeric,
  "Market_Capitalization" numeric
);

ALTER TABLE "annual_p_l_2" ADD FOREIGN KEY ("join_key") REFERENCES "annual_p_l_1" ("join_key");
    """
    cursor.execute(create_table_query)
    conn.commit()

    # Insert data into the table
    insert_query = """
    INSERT INTO annual_p_l_1 (  join_key,
  Name,
 BSE_Code,
  NSE_Code,
  Industry,
  Main Industry,
 Sub Industry ,
  Current_Price,
  Sales,
  OPM,
Profit_after_tax,
Return_on_capital_employed,
EPS,
Change_in_promoter_holding,
Sales_last_year,
Operating_profit_last_year,
Other_income_last_year,
EBIDT_last_year,
Depreciation_last_year,
EBIT_last_year,
Interest_last_year,
Profit_before_tax_last_year,
Tax_last_year,
Profit_after_tax_last_year,
Extraordinary_items_last_year,
Net_Profit_last_year,
Dividend_last_year,
Material_cost_last_year,
Employee_cost_last_year,
OPM_last_year,
NPM_last_year,
Operating_profit,
Interest,
Depreciation,
EPS_last_year,
EBIT,
Net_profit,
Current_Tax,
Tax,
Other_income,
Last_annual_result_date,
Sales_preceding_year,
Operating_profit_preceding_year,
Other_income_preceding_year,
EBIDT_preceding_year,
Depreciation_preceding_year,
EBIT_preceding_year,
Interest_preceding_year,
Profit_before_tax_preceding_year,
Tax_preceding_year,
Profit_after_tax_preceding_year,
Extraordinary_items_preceding_year,
Net_Profit_preceding_year,
Dividend_preceding_year,
OPM_preceding_year,
NPM_preceding_year,
EPS_preceding_year,
Sales_preceding_12months,
Net_profit_preceding_12months,
Difference in Net Profit btw Last Year and Preceeding Year,
Market_Capitalization
)
INSERT INTO annual_p_l_2 ( join_key,
Name,
BSE_Code,
NSE_Code,
Industry,
Main Industry,
Sub Industry,
Current_Price,
Sales_growth_3Years,
Growth/Decline (3 years)?,
Sales_growth_5Years,
Profit_growth_3Years,
Profit_growth_5Years,
Sales_growth_10years_median,
Sales_growth_5years_median,
Sales_growth_7Years,
Sales_growth_10Years,
EBIDT_growth_3Years,
EBIDT_growth_5Years,
EBIDT_growth_7Years,
EBIDT_growth_10Years,
EPS_growth_3Years,
EPS_growth_5Years,
EPS_growth_7Years,
EPS_growth_10Years,
Profit_growth_7Years,
Profit_growth_10Years,
Change_in_promoter_holding_3Years,
Average_Earnings_5Year,
Average_Earnings_10Year,
Average_EBIT_5Year,
Average_EBIT_10Year,
Market_Capitalization)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
    """
    for _, row in filtered_P1_data.iterrows():
        cursor.execute(insert_query, (row['join_key'],
row['Name'],
row['BSE_Code'],
row['NSE_Code'],
row['Industry'],
row['Main Industry'],
row['Sub Industry'],
row['Current_Price'],
row['Sales'],
row['OPM'],
row['Profit_after_tax'],
row['Return_on_capital_employed'],
row['EPS'],
row['Change_in_promoter_holding'],
row['Sales_last_year'],
row['Operating_profit_last_year'],
row['Other_income_last_year'],
row['EBIDT_last_year'],
row['Depreciation_last_year'],
row['EBIT_last_year'],
row['Interest_last_year'],
row['Profit_before_tax_last_year'],
row['Tax_last_year'],
row['Profit_after_tax_last_year'],
row['Extraordinary_items_last_year'],
row['Net_Profit_last_year'],
row['Dividend_last_year'],
row['Material_cost_last_year'],
row['Employee_cost_last_year'],
row['OPM_last_year'],
row['NPM_last_year'],
row['Operating_profit'],
row['Interest'],
row['Depreciation'],
row['EPS_last_year'],
row['EBIT'],
row['Net_profit'],
row['Current_Tax'],
row['Tax'],
row['Other_income'],
row['Last_annual_result_date'],
row['Sales_preceding_year'],
row['Operating_profit_preceding_year'],
row['Other_income_preceding_year'],
row['EBIDT_preceding_year'],
row['Depreciation_preceding_year'],
row['EBIT_preceding_year'],
row['Interest_preceding_year'],
row['Profit_before_tax_preceding_year'],
row['Tax_preceding_year'],
row['Profit_after_tax_preceding_year'],
row['Extraordinary_items_preceding_year'],
row['Net_Profit_preceding_year'],
row['Dividend_preceding_year'],
row['OPM_preceding_year'],
row['NPM_preceding_year'],
row['EPS_preceding_year'],
row['Sales_preceding_12months'],
row['Net_profit_preceding_12months'],
row['Difference in Net Profit btw Last Year and Preceeding Year'],
row['Market_Capitalization'],
), (row['join_key'],
row['Name'],
row['BSE_Code'],
row['NSE_Code'],
row['Industry'],
row['Main Industry'],
row['Sub Industry'],
row['Current_Price'],
row['Sales_growth_3Years'],
row['Growth/Decline (3 years)?'],
row['Sales_growth_5Years'],
row['Profit_growth_3Years'],
row['Profit_growth_5Years'],
row['Sales_growth_10years_median'],
row['Sales_growth_5years_median'],
row['Sales_growth_7Years'],
row['Sales_growth_10Years'],
row['EBIDT_growth_3Years'],
row['EBIDT_growth_5Years'],
row['EBIDT_growth_7Years'],
row['EBIDT_growth_10Years'],
row['EPS_growth_3Years'],
row['EPS_growth_5Years'],
row['EPS_growth_7Years'],
row['EPS_growth_10Years'],
row['Profit_growth_7Years'],
row['Profit_growth_10Years'],
row['Change_in_promoter_holding_3Years'],
row['Average_Earnings_5Year'],
row['Average_Earnings_10Year'],
row['Average_EBIT_5Year'],
row['Average_EBIT_10Year'],
row['Market_Capitalization']
   ))

    conn.commit()
    print("Data inserted successfully")

except Exception as e:
    print(f"An error occurred: {e}")
finally:
    # Close the connection
    if conn:
        cursor.close()
        conn.close()
        print("Connection closed")
